# %%
import matplotlib.pyplot as plt

# %%
import xarray as xr
import numpy as np

# %%
ds = xr.open_dataset("data/blt1_mb.nc")

# %%
plt.figure(figsize=(16, 10))
pc = (-da).plot()
pc.set_clim(1000, 2200)
pc = ds['z'].plot()
pc.set_clim(1000, 2200)
ds['z'].plot.contour(levels=np.arange(1000, 2200, 100), colors="k")
#plt.xlim(-12.1, -11.7)
#plt.ylim(54.15, 54.3)

# %%
da = xr.open_dataarray("data/rockall_bathy.nc")

# %%
ds['z']
# Out:
# <xarray.DataArray 'z' (lat: 392, lon: 718)>
# array([[      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        ...,
#        [2958.3352, 2956.7754, 2956.612 , ...,       nan,       nan,       nan],
#        [2957.8232, 2955.547 , 2957.1067, ...,       nan,       nan,       nan],
#        [2955.4482, 2955.9197, 2953.8562, ...,       nan,       nan,       nan]],
#       dtype=float32)
# Coordinates:
#   * lat      (lat) float64 54.1 54.1 54.1 54.1 54.1 ... 54.4 54.4 54.4 54.4 54.4
#   * lon      (lon) float64 -12.3 -12.3 -12.3 -12.3 ... -11.75 -11.75 -11.75
